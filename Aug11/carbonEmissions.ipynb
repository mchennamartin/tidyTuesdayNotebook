# %%
import pydytuesday
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
import plotly as ptly

#file locations
main = os.getcwd()

# Download files from the week, which you can then read in locally
pydytuesday.get_date('2025-08-12')

data = pd.read_csv('attribution_studies.csv')
print(data)
# Out:
# Trying to fetch README from: https://raw.githubusercontent.com/rfordatascience/tidytuesday/refs/heads/main/data/2025/2025-08-12/readme.md
# Successfully fetched README from: https://raw.githubusercontent.com/rfordatascience/tidytuesday/refs/heads/main/data/2025/2025-08-12/readme.md
# Downloading attribution_studies.csv...
# Successfully saved attribution_studies.csv to C:\Users\mchen\PycharmProjects\tidyTuesday\attribution_studies.csv
# Downloading attribution_studies_raw.csv...
# Successfully saved attribution_studies_raw.csv to C:\Users\mchen\PycharmProjects\tidyTuesday\attribution_studies_raw.csv
# Downloading extremes.png...
# Successfully saved extremes.png to C:\Users\mchen\PycharmProjects\tidyTuesday\extremes.png
# Downloading meta.yaml...
# Successfully saved meta.yaml to C:\Users\mchen\PycharmProjects\tidyTuesday\meta.yaml
#                                             event_name event_period  \
# 0                             European summer heatwave         2003
# 1                          Global temperature extremes   since 1950
# 2                         Record warm autumn in Europe         2006
# 3    Increasing frequency of 'very warm' Northern h...    1860-2009
# 4                               Moscow summer heatwave         2010
# ..                                                 ...          ...
# 739            China growing season hot and dry events    mid 1990s
# 740                               China hot-wet events    1979-2014
# 741  Heat extremes behind bleaching of the Great Ba...   2020, 2024
# 742  Heat-related neonatal deaths in low- and middl...    2001-2019
# 743              Hospitalisations in China due to heat    2000-2019
#
#            event_year study_focus iso_country_code  \
# 0                2003       Event              NaN
# 1                 NaN       Trend              NaN
# 2                2006       Event              NaN
# 3                 NaN       Trend              NaN
# 4                2010       Event              RUS
# ..                ...         ...              ...
# 739         Mid-1990s       Event              CHN
# 740               NaN       Trend              CHN
# 741  2017, 2020, 2024       Event              AUS
# 742               NaN       Trend              NaN
# 743               NaN       Trend              CHN
#
#                           cb_region event_type  \
# 0                            Europe       Heat
# 1                            Global       Heat
# 2                            Europe       Heat
# 3               Northern hemisphere       Heat
# 4                            Europe       Heat
# ..                              ...        ...
# 739  Eastern and south-eastern Asia   Compound
# 740  Eastern and south-eastern Asia   Compound
# 741       Australia and New Zealand     Impact
# 742                          Global     Impact
# 743  Eastern and south-eastern Asia     Impact
#
#                                     classification  \
# 0              More severe or more likely to occur
# 1              More severe or more likely to occur
# 2              More severe or more likely to occur
# 3              More severe or more likely to occur
# 4              More severe or more likely to occur
# ..                                             ...
# 739            More severe or more likely to occur
# 740  Decrease, less severe or less likely to occur
# 741            More severe or more likely to occur
# 742            More severe or more likely to occur
# 743            More severe or more likely to occur
#
#                                      summary_statement  publication_year  \
# 0    "We estimate it is very likely (confidence lev...            2004.0
# 1    "Comparing these observations with climate mod...            2005.0
# 2    "Global warming has made a warm autumn like th...            2007.0
# 3    "We detect the dominant influence of anthropog...            2007.0
# 4    "For July temperature in Moscow, we estimate.....            2011.0
# ..                                                 ...               ...
# 739  "Anthropogenic forcing changes can explain 60%...            2024.0
# 740  "Over the past 40 years, anthropogenic activit...            2024.0
# 741  "Climate model analysis confirms that human in...            2024.0
# 742  "Climate change was responsible for 32% (range...            2024.0
# 743  "In the 2010s, the heat-related attributable f...            2024.0
#
#                                               citation  \
# 0    Stott, P. et al., 2004: Human contribution to ...
# 1    Christidis, N. et al., 2005: Detection of chan...
# 2    Van Oldenborgh, G-J. et al., 2007: How unusual...
# 3    Jones, G. et al., 2007: Human contribution to ...
# 4    Rahmstorf, S. & Coumou, D. 2011: Increase of e...
# ..                                                 ...
# 739  Su Q. et al., 2024: Anthropogenic Influence on...
# 740  Yao H. et al., 2024: Changes caused by human a...
# 741  Henley B.J. et al., 2024: Highest ocean heat i...
# 742  Dimitrova. A. et al., 2024: Temperature-relate...
# 743  Zhou. L. et al,. 2024: Quantification of the H...
#
#                                               source rapid_study  \
# 0                                             Nature          No
# 1                       Geophysical Research Letters          No
# 2                                Climate of the Past          No
# 3       Journal of Geophysical Research: Atmospheres          No
# 4    Proceedings of the National Academy of Sciences          No
# ..                                               ...         ...
# 739                 Advances in Atmospheric Sciences          No
# 740               Communications Earth & Environment          No
# 741                                           Nature          No
# 742                            Nature Communications          No
# 743                Environmental Health Perspectives          No
#
#                                                   link
# 0    https://www.nature.com/nature/journal/v432/n70...
# 1    https://agupubs.onlinelibrary.wiley.com/doi/fu...
# 2    http://www.clim-past.net/3/659/2007/cp-3-659-2...
# 3    https://agupubs.onlinelibrary.wiley.com/doi/fu...
# 4    http://www.pnas.org/content/108/44/17905.abstract
# ..                                                 ...
# 739          https://doi.org/10.1007/s00376-023-2319-z
# 740         https://doi.org/10.1038/s43247-024-01625-y
# 741         https://doi.org/10.1038/s41586-024-07672-x
# 742  https://www.nature.com/articles/s41467-024-498...
# 743     https://ehp.niehs.nih.gov/doi/10.1289/EHP14057
#
# [744 rows x 14 columns]
